# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

nation_2018 = pd.read_csv('data/2018_immigrants_nacionalitats.csv')
nation_2017 = pd.read_csv('data/2017_immigrants_nacionalitats.csv')
nation_2016 = pd.read_csv('data/2016_immigrants_nacionalitats.csv')
nation_2015 = pd.read_csv('data/2015_immigrants_nacionalitats.csv')
nation = pd.concat([nation_2018, nation_2017, nation_2016, nation_2015])

nation.info()
nation.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35370 entries, 0 to 11395
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             35370 non-null  int64
#  1   Codi_Districte  35370 non-null  int64
#  2   Nom_Districte   35370 non-null  object
#  3   Codi_Barri      35370 non-null  int64
#  4   Nom_Barri       35370 non-null  object
#  5   Nacionalitat    35370 non-null  object
#  6   Nombre          35370 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 2.2+ MB
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri Nacionalitat  Nombre
# ...
